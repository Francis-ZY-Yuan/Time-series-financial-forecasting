# %%
import pandas as pd
import requests
import json

# %%
# Key file not included in repo
with open("./API_key") as fin:
    key = fin.read().strip()

# %% [markdown]
# # Get the stock symbols for `S&P 500`

# %%
resp = json.loads(
    requests.get(f"https://eodhistoricaldata.com/api/fundamentals/GSPC.INDX?api_token={key}").text
)

# %%
symbols = [c["Code"] for c in resp["Components"].values()]
print(f"Got {len(symbols)} stocks in total\nExample: {symbols[:5]}")
# Out:
# Got 503 stocks in total
# Example: ['AIZ', 'MNST', 'MTCH', 'PGR', 'FISV']

# %% [markdown]
# # Get fundamentals data

# %%
import tqdm.notebook

# %%
fundamentals = {}

# %%
for sym in tqdm.notebook.tqdm(symbols):
    if sym in fundamentals:
        continue
        
    resp = json.loads(
        requests.get(f"https://eodhistoricaldata.com/api/fundamentals/{sym}?api_token={key}").text
    )
    
    fundamentals[sym] = resp
# Out:
#   0%|          | 0/503 [00:00<?, ?it/s]

# %%
# %%time
with open("./fundamentals_SP500.json", "w") as fout:
    json.dump(fundamentals, fout)
# Out:
# CPU times: total: 766 ms
# Wall time: 2min 8s

# %%
# %%time
with open("./fundamentals_SP500.json", "r") as fin:
    fundamentals = json.load(fin)
# Out:
# CPU times: total: 2.33 s
# Wall time: 3.32 s

# %% [markdown]
# # Convert JSON to DataFrame

# %%
js = fundamentals["A"]

# %%
js['Financials']["Balance_Sheet"]["quarterly"]
# Out:
# {'2022-07-31': {'date': '2022-07-31',
#   'filing_date': '2022-09-01',
#   'currency_symbol': 'USD',
#   'totalAssets': '10484000000.00',
#   'intangibleAssets': '849000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '258000000.00',
#   'totalLiab': '5393000000.00',
#   'totalStockholderEquity': '5091000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '666000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': '3000000.00',
#   'retainedEarnings': '139000000.00',
#   'otherLiab': '759000000.00',
#   'goodWill': '3948000000.00',
#   'otherAssets': '749000000.00',
#   'cash': '1071000000.00',
#   'cashAndEquivalents': '1071000000.00',
#   'totalCurrentLiabilities': '1902000000.00',
#   'currentDeferredRevenue': '498000000.00',
#   'netDebt': '1841000000.00',
#   'shortTermDebt': '180000000.00',
#   'shortLongTermDebt': '180000000.00',
#   'shortLongTermDebtTotal': '2912000000.00',
#   'otherStockholderEquity': '5311000000.00',
#   'propertyPlantEquipment': '1054000000.00',
#   'totalCurrentAssets': '3690000000.00',
#   'longTermInvestments': '194000000.00',
#   'netTangibleAssets': '294000000.00',
#   'shortTermInvestments': '6000000.00',
#   'netReceivables': '1345000000.00',
#   'longTermDebt': '2732000000.00',
#   'inventory': '1010000000.00',
#   'accountsPayable': '558000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-362000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '139000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '749000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6794000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2732000000.00',
#   'nonCurrentLiabilitiesOther': '583000000.00',
#   'nonCurrentLiabilitiesTotal': '3491000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5311000000.00',
#   'liabilitiesAndStockholdersEquity': '10484000000.00',
#   'cashAndShortTermInvestments': '1077000000.00',
#   'propertyPlantAndEquipmentGross': None,
#   'propertyPlantAndEquipmentNet': '1054000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1788000000.00',
#   'netInvestedCapital': '8003000000.00',
#   'commonStockSharesOutstanding': '299000000.00'},
#  '2022-04-30': {'date': '2022-04-30',
#   'filing_date': '2022-05-31',
#   'currency_symbol': 'USD',
#   'totalAssets': '10455000000.00',
#   'intangibleAssets': '898000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '262000000.00',
#   'totalLiab': '5333000000.00',
#   'totalStockholderEquity': '5122000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '624000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': '3000000.00',
#   'retainedEarnings': '160000000.00',
#   'otherLiab': '790000000.00',
#   'goodWill': '3956000000.00',
#   'otherAssets': '758000000.00',
#   'cash': '1186000000.00',
#   'cashAndEquivalents': '1186000000.00',
#   'totalCurrentLiabilities': '1813000000.00',
#   'currentDeferredRevenue': '511000000.00',
#   'netDebt': '1719000000.00',
#   'shortTermDebt': '175000000.00',
#   'shortLongTermDebt': '175000000.00',
#   'shortLongTermDebtTotal': '2905000000.00',
#   'otherStockholderEquity': '5292000000.00',
#   'propertyPlantEquipment': '1010000000.00',
#   'totalCurrentAssets': '3643000000.00',
#   'longTermInvestments': '190000000.00',
#   'netTangibleAssets': '268000000.00',
#   'shortTermInvestments': '21000000.00',
#   'netReceivables': '1237000000.00',
#   'longTermDebt': '2730000000.00',
#   'inventory': '937000000.00',
#   'accountsPayable': '503000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-333000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': None,
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '758000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6812000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2730000000.00',
#   'nonCurrentLiabilitiesOther': '603000000.00',
#   'nonCurrentLiabilitiesTotal': '3520000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5292000000.00',
#   'liabilitiesAndStockholdersEquity': '10455000000.00',
#   'cashAndShortTermInvestments': '1207000000.00',
#   'propertyPlantAndEquipmentGross': None,
#   'propertyPlantAndEquipmentNet': '1010000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1830000000.00',
#   'netInvestedCapital': '8027000000.00',
#   'commonStockSharesOutstanding': '301000000.00'},
#  '2022-01-31': {'date': '2022-01-31',
#   'filing_date': '2022-03-03',
#   'currency_symbol': 'USD',
#   'totalAssets': '10327000000.00',
#   'intangibleAssets': '929000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '232000000.00',
#   'totalLiab': '5173000000.00',
#   'totalStockholderEquity': '5154000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '616000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': '3000000.00',
#   'retainedEarnings': '159000000.00',
#   'otherLiab': '859000000.00',
#   'goodWill': '4893000000.00',
#   'otherAssets': '795000000.00',
#   'cash': '1113000000.00',
#   'cashAndEquivalents': '1113000000.00',
#   'totalCurrentLiabilities': '1584000000.00',
#   'currentDeferredRevenue': '493000000.00',
#   'netDebt': '1617000000.00',
#   'shortTermDebt': '0.00',
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '2730000000.00',
#   'otherStockholderEquity': '5290000000.00',
#   'propertyPlantEquipment': '974000000.00',
#   'totalCurrentAssets': '3474000000.00',
#   'longTermInvestments': '191000000.00',
#   'netTangibleAssets': '261000000.00',
#   'shortTermInvestments': '45000000.00',
#   'netReceivables': '1205000000.00',
#   'longTermDebt': '2730000000.00',
#   'inventory': '879000000.00',
#   'accountsPayable': '475000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-298000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '159000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '-134000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6853000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2730000000.00',
#   'nonCurrentLiabilitiesOther': '653000000.00',
#   'nonCurrentLiabilitiesTotal': '3589000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5290000000.00',
#   'liabilitiesAndStockholdersEquity': '10327000000.00',
#   'cashAndShortTermInvestments': '1158000000.00',
#   'propertyPlantAndEquipmentGross': None,
#   'propertyPlantAndEquipmentNet': '974000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1890000000.00',
#   'netInvestedCapital': '7884000000.00',
#   'commonStockSharesOutstanding': '303000000.00'},
#  '2021-10-31': {'date': '2021-10-31',
#   'filing_date': '2021-12-17',
#   'currency_symbol': 'USD',
#   'totalAssets': '10705000000.00',
#   'intangibleAssets': '981000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '222000000.00',
#   'totalLiab': '5316000000.00',
#   'totalStockholderEquity': '5389000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '821000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': '3000000.00',
#   'retainedEarnings': '348000000.00',
#   'otherLiab': '879000000.00',
#   'goodWill': '3975000000.00',
#   'otherAssets': '820000000.00',
#   'cash': '1484000000.00',
#   'cashAndEquivalents': '1484000000.00',
#   'totalCurrentLiabilities': '1708000000.00',
#   'currentDeferredRevenue': '441000000.00',
#   'netDebt': '1245000000.00',
#   'shortTermDebt': '0.00',
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '2729000000.00',
#   'otherStockholderEquity': '5320000000.00',
#   'propertyPlantEquipment': '945000000.00',
#   'totalCurrentAssets': '3799000000.00',
#   'longTermInvestments': '185000000.00',
#   'netTangibleAssets': '433000000.00',
#   'shortTermInvestments': '91000000.00',
#   'netReceivables': '1172000000.00',
#   'longTermDebt': '2729000000.00',
#   'inventory': '830000000.00',
#   'accountsPayable': '446000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-282000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '348000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '820000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6906000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2729000000.00',
#   'nonCurrentLiabilitiesOther': '659000000.00',
#   'nonCurrentLiabilitiesTotal': '3608000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5320000000.00',
#   'liabilitiesAndStockholdersEquity': '10705000000.00',
#   'cashAndShortTermInvestments': '1575000000.00',
#   'propertyPlantAndEquipmentGross': None,
#   'propertyPlantAndEquipmentNet': '945000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '2091000000.00',
#   'netInvestedCapital': '8118000000.00',
#   'commonStockSharesOutstanding': '305000000.00'},
#  '2021-07-31': {'date': '2021-07-31',
#   'filing_date': '2021-09-01',
#   'currency_symbol': 'USD',
#   'totalAssets': '10491000000.00',
#   'intangibleAssets': '1032000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '264000000.00',
#   'totalLiab': '5545000000.00',
#   'totalStockholderEquity': '4946000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '735000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': '3000000.00',
#   'retainedEarnings': '90000000.00',
#   'otherLiab': '1093000000.00',
#   'goodWill': '3976000000.00',
#   'otherAssets': '742000000.00',
#   'cash': '1428000000.00',
#   'cashAndEquivalents': '1428000000.00',
#   'totalCurrentLiabilities': '1724000000.00',
#   'currentDeferredRevenue': '443000000.00',
#   'netDebt': '1430000000.00',
#   'shortTermDebt': '130000000.00',
#   'shortLongTermDebt': '130000000.00',
#   'shortLongTermDebtTotal': '2858000000.00',
#   'otherStockholderEquity': '5307000000.00',
#   'propertyPlantEquipment': '905000000.00',
#   'totalCurrentAssets': '3632000000.00',
#   'longTermInvestments': '204000000.00',
#   'netTangibleAssets': '-62000000.00',
#   'shortTermInvestments': '204000000.00',
#   'netReceivables': '1122000000.00',
#   'longTermDebt': '2728000000.00',
#   'inventory': '818000000.00',
#   'accountsPayable': '416000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-454000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '90000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '742000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6859000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2728000000.00',
#   'nonCurrentLiabilitiesOther': '728000000.00',
#   'nonCurrentLiabilitiesTotal': '3821000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5307000000.00',
#   'liabilitiesAndStockholdersEquity': '10491000000.00',
#   'cashAndShortTermInvestments': '1428000000.00',
#   'propertyPlantAndEquipmentGross': '905000000.00',
#   'propertyPlantAndEquipmentNet': '905000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1908000000.00',
#   'netInvestedCapital': '7804000000.00',
#   'commonStockSharesOutstanding': '306000000.00'},
#  '2021-04-30': {'date': '2021-04-30',
#   'filing_date': '2021-06-01',
#   'currency_symbol': 'USD',
#   'totalAssets': '10398000000.00',
#   'intangibleAssets': '1005000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '268000000.00',
#   'totalLiab': '5588000000.00',
#   'totalStockholderEquity': '4810000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '701000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': '3000000.00',
#   'retainedEarnings': '-12000000.00',
#   'otherLiab': '912000000.00',
#   'goodWill': '4054000000.00',
#   'otherAssets': '567000000.00',
#   'cash': '1380000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1758000000.00',
#   'currentDeferredRevenue': '429000000.00',
#   'netDebt': '1552000000.00',
#   'shortTermDebt': '205000000.00',
#   'shortLongTermDebt': '205000000.00',
#   'shortLongTermDebtTotal': '2932000000.00',
#   'otherStockholderEquity': '5271000000.00',
#   'propertyPlantEquipment': '1070000000.00',
#   'totalCurrentAssets': '3514000000.00',
#   'longTermInvestments': '188000000.00',
#   'netTangibleAssets': '-249000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '1075000000.00',
#   'longTermDebt': '2727000000.00',
#   'inventory': '791000000.00',
#   'accountsPayable': '423000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-452000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '753000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6884000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2727000000.00',
#   'nonCurrentLiabilitiesOther': '726000000.00',
#   'nonCurrentLiabilitiesTotal': '3830000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5271000000.00',
#   'liabilitiesAndStockholdersEquity': '10398000000.00',
#   'cashAndShortTermInvestments': '1380000000.00',
#   'propertyPlantAndEquipmentGross': '884000000.00',
#   'propertyPlantAndEquipmentNet': '884000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1756000000.00',
#   'netInvestedCapital': '7742000000.00',
#   'commonStockSharesOutstanding': '307000000.00'},
#  '2021-01-31': {'date': '2021-01-31',
#   'filing_date': '2021-03-02',
#   'currency_symbol': 'USD',
#   'totalAssets': '9674000000.00',
#   'intangibleAssets': '787000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '147000000.00',
#   'totalLiab': '4870000000.00',
#   'totalStockholderEquity': '4804000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '556000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '4000000.00',
#   'otherLiab': '998000000.00',
#   'goodWill': '3618000000.00',
#   'otherAssets': '755000000.00',
#   'cash': '1329000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1687000000.00',
#   'currentDeferredRevenue': '419000000.00',
#   'netDebt': '1170000000.00',
#   'shortTermDebt': '314000000.00',
#   'shortLongTermDebt': '314000000.00',
#   'shortLongTermDebtTotal': '2499000000.00',
#   'otherStockholderEquity': '5266000000.00',
#   'propertyPlantEquipment': '866000000.00',
#   'totalCurrentAssets': '3483000000.00',
#   'longTermInvestments': '165000000.00',
#   'netTangibleAssets': '399000000.00',
#   'shortTermInvestments': '165000000.00',
#   'netReceivables': '1087000000.00',
#   'longTermDebt': '2185000000.00',
#   'inventory': '755000000.00',
#   'accountsPayable': '398000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-469000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '4000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '755000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6191000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2185000000.00',
#   'nonCurrentLiabilitiesOther': '998000000.00',
#   'nonCurrentLiabilitiesTotal': '3183000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5266000000.00',
#   'liabilitiesAndStockholdersEquity': '9674000000.00',
#   'cashAndShortTermInvestments': '1494000000.00',
#   'propertyPlantAndEquipmentGross': '866000000.00',
#   'propertyPlantAndEquipmentNet': '866000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1796000000.00',
#   'netInvestedCapital': '7303000000.00',
#   'commonStockSharesOutstanding': '309000000.00'},
#  '2020-10-31': {'date': '2020-10-31',
#   'filing_date': '2020-12-18',
#   'currency_symbol': 'USD',
#   'totalAssets': '9627000000.00',
#   'intangibleAssets': '831000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '58000000.00',
#   'totalLiab': '4754000000.00',
#   'totalStockholderEquity': '4873000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '652000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '81000000.00',
#   'otherLiab': '876000000.00',
#   'goodWill': '3602000000.00',
#   'otherAssets': '601000000.00',
#   'cash': '1441000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1467000000.00',
#   'currentDeferredRevenue': '386000000.00',
#   'netDebt': '918000000.00',
#   'shortTermDebt': '75000000.00',
#   'shortLongTermDebt': '75000000.00',
#   'shortLongTermDebtTotal': '2359000000.00',
#   'otherStockholderEquity': '5311000000.00',
#   'propertyPlantEquipment': '845000000.00',
#   'totalCurrentAssets': '3415000000.00',
#   'longTermInvestments': '158000000.00',
#   'netTangibleAssets': '440000000.00',
#   'shortTermInvestments': '158000000.00',
#   'netReceivables': '1038000000.00',
#   'longTermDebt': '2284000000.00',
#   'inventory': '720000000.00',
#   'accountsPayable': '354000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-522000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '81000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '776000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6212000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2284000000.00',
#   'nonCurrentLiabilitiesOther': '1003000000.00',
#   'nonCurrentLiabilitiesTotal': '3287000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5311000000.00',
#   'liabilitiesAndStockholdersEquity': '9627000000.00',
#   'cashAndShortTermInvestments': '1599000000.00',
#   'propertyPlantAndEquipmentGross': '845000000.00',
#   'propertyPlantAndEquipmentNet': '845000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1948000000.00',
#   'netInvestedCapital': '7232000000.00',
#   'commonStockSharesOutstanding': '311000000.00'},
#  '2020-07-31': {'date': '2020-07-31',
#   'filing_date': '2020-09-01',
#   'currency_symbol': 'USD',
#   'totalAssets': '9546000000.00',
#   'intangibleAssets': '876000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '211000000.00',
#   'totalLiab': '4565000000.00',
#   'totalStockholderEquity': '4981000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '566000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '130000000.00',
#   'otherLiab': '835000000.00',
#   'goodWill': '3606000000.00',
#   'otherAssets': '642000000.00',
#   'cash': '1358000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1314000000.00',
#   'currentDeferredRevenue': '397000000.00',
#   'netDebt': '965000000.00',
#   'shortTermDebt': '40000000.00',
#   'shortLongTermDebt': '40000000.00',
#   'shortLongTermDebtTotal': '2323000000.00',
#   'otherStockholderEquity': '5324000000.00',
#   'propertyPlantEquipment': '1029000000.00',
#   'totalCurrentAssets': '3245000000.00',
#   'longTermInvestments': '148000000.00',
#   'netTangibleAssets': '499000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '930000000.00',
#   'longTermDebt': '2283000000.00',
#   'inventory': '746000000.00',
#   'accountsPayable': '311000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-476000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '130000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '825000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6301000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '2283000000.00',
#   'nonCurrentLiabilitiesOther': '613000000.00',
#   'nonCurrentLiabilitiesTotal': '3251000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5324000000.00',
#   'liabilitiesAndStockholdersEquity': '9546000000.00',
#   'cashAndShortTermInvestments': '1358000000.00',
#   'propertyPlantAndEquipmentGross': '846000000.00',
#   'propertyPlantAndEquipmentNet': '846000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1931000000.00',
#   'netInvestedCapital': '7304000000.00',
#   'commonStockSharesOutstanding': '312000000.00'},
#  '2020-04-30': {'date': '2020-04-30',
#   'filing_date': '2020-06-01',
#   'currency_symbol': 'USD',
#   'totalAssets': '9455000000.00',
#   'intangibleAssets': '921000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '211000000.00',
#   'totalLiab': '4687000000.00',
#   'totalStockholderEquity': '4768000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '513000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '15000000.00',
#   'otherLiab': '816000000.00',
#   'goodWill': '3582000000.00',
#   'otherAssets': '616000000.00',
#   'cash': '1324000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1945000000.00',
#   'currentDeferredRevenue': '399000000.00',
#   'netDebt': '1164000000.00',
#   'shortTermDebt': '700000000.00',
#   'shortLongTermDebt': '700000000.00',
#   'shortLongTermDebtTotal': '2488000000.00',
#   'otherStockholderEquity': '5288000000.00',
#   'propertyPlantEquipment': '836000000.00',
#   'totalCurrentAssets': '3171000000.00',
#   'longTermInvestments': '141000000.00',
#   'netTangibleAssets': '265000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '886000000.00',
#   'longTermDebt': '1788000000.00',
#   'inventory': '750000000.00',
#   'accountsPayable': '333000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-538000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '15000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '804000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6284000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1788000000.00',
#   'nonCurrentLiabilitiesOther': '954000000.00',
#   'nonCurrentLiabilitiesTotal': '2742000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5288000000.00',
#   'liabilitiesAndStockholdersEquity': '9455000000.00',
#   'cashAndShortTermInvestments': '1324000000.00',
#   'propertyPlantAndEquipmentGross': '836000000.00',
#   'propertyPlantAndEquipmentNet': '836000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1226000000.00',
#   'netInvestedCapital': '7256000000.00',
#   'commonStockSharesOutstanding': '312000000.00'},
#  '2020-01-31': {'date': '2020-01-31',
#   'filing_date': '2020-03-03',
#   'currency_symbol': 'USD',
#   'totalAssets': '9501000000.00',
#   'intangibleAssets': '1059000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '204000000.00',
#   'totalLiab': '4653000000.00',
#   'totalStockholderEquity': '4848000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '509000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '73000000.00',
#   'otherLiab': '833000000.00',
#   'goodWill': '3589000000.00',
#   'otherAssets': '598000000.00',
#   'cash': '1226000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1892000000.00',
#   'currentDeferredRevenue': '379000000.00',
#   'netDebt': '1236000000.00',
#   'shortTermDebt': '675000000.00',
#   'shortLongTermDebt': '675000000.00',
#   'shortLongTermDebtTotal': '2462000000.00',
#   'otherStockholderEquity': '5293000000.00',
#   'propertyPlantEquipment': '844000000.00',
#   'totalCurrentAssets': '3102000000.00',
#   'longTermInvestments': '118000000.00',
#   'netTangibleAssets': '200000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '966000000.00',
#   'longTermDebt': '1787000000.00',
#   'inventory': '706000000.00',
#   'accountsPayable': '329000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-521000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '73000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '789000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6399000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1787000000.00',
#   'nonCurrentLiabilitiesOther': '974000000.00',
#   'nonCurrentLiabilitiesTotal': '2761000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5293000000.00',
#   'liabilitiesAndStockholdersEquity': '9501000000.00',
#   'cashAndShortTermInvestments': '1226000000.00',
#   'propertyPlantAndEquipmentGross': '844000000.00',
#   'propertyPlantAndEquipmentNet': '844000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': '1210000000.00',
#   'netInvestedCapital': '7310000000.00',
#   'commonStockSharesOutstanding': '313000000.00'},
#  '2019-10-31': {'date': '2019-10-31',
#   'filing_date': '2019-12-19',
#   'currency_symbol': 'USD',
#   'totalAssets': '9452000000.00',
#   'intangibleAssets': '1107000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '198000000.00',
#   'totalLiab': '4704000000.00',
#   'totalStockholderEquity': '4748000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '774000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '-18000000.00',
#   'otherLiab': '833000000.00',
#   'goodWill': '3593000000.00',
#   'otherAssets': '611000000.00',
#   'cash': '1382000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '2080000000.00',
#   'currentDeferredRevenue': '336000000.00',
#   'netDebt': '1025000000.00',
#   'shortTermDebt': '616000000.00',
#   'shortLongTermDebt': '616000000.00',
#   'shortLongTermDebtTotal': '2407000000.00',
#   'otherStockholderEquity': '5277000000.00',
#   'propertyPlantEquipment': '850000000.00',
#   'totalCurrentAssets': '3189000000.00',
#   'longTermInvestments': '102000000.00',
#   'netTangibleAssets': '48000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '930000000.00',
#   'longTermDebt': '1791000000.00',
#   'inventory': '679000000.00',
#   'accountsPayable': '354000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-514000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '-18000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '611000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '6263000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1791000000.00',
#   'nonCurrentLiabilitiesOther': '833000000.00',
#   'nonCurrentLiabilitiesTotal': '2624000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5277000000.00',
#   'liabilitiesAndStockholdersEquity': '9452000000.00',
#   'cashAndShortTermInvestments': '1382000000.00',
#   'propertyPlantAndEquipmentGross': '850000000.00',
#   'propertyPlantAndEquipmentNet': '850000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '313000000.00'},
#  '2019-07-31': {'date': '2019-07-31',
#   'filing_date': '2019-08-30',
#   'currency_symbol': 'USD',
#   'totalAssets': '8625000000.00',
#   'intangibleAssets': '511000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '176000000.00',
#   'totalLiab': '3878000000.00',
#   'totalStockholderEquity': '4747000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '458000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '-122000000.00',
#   'otherLiab': '962000000.00',
#   'goodWill': '3107000000.00',
#   'otherAssets': '612000000.00',
#   'cash': '1765000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1622000000.00',
#   'currentDeferredRevenue': '344000000.00',
#   'netDebt': '33000000.00',
#   'shortTermDebt': '504000000.00',
#   'shortLongTermDebt': '504000000.00',
#   'shortLongTermDebtTotal': '1798000000.00',
#   'otherStockholderEquity': '5270000000.00',
#   'propertyPlantEquipment': '839000000.00',
#   'totalCurrentAssets': '3457000000.00',
#   'longTermInvestments': '99000000.00',
#   'netTangibleAssets': '1129000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '856000000.00',
#   'longTermDebt': '1294000000.00',
#   'inventory': '660000000.00',
#   'accountsPayable': '316000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-404000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '-122000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '612000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '5168000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1294000000.00',
#   'nonCurrentLiabilitiesOther': '962000000.00',
#   'nonCurrentLiabilitiesTotal': '2256000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5270000000.00',
#   'liabilitiesAndStockholdersEquity': '8625000000.00',
#   'cashAndShortTermInvestments': '1765000000.00',
#   'propertyPlantAndEquipmentGross': '839000000.00',
#   'propertyPlantAndEquipmentNet': '839000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '316000000.00'},
#  '2019-04-30': {'date': '2019-04-30',
#   'filing_date': '2019-05-30',
#   'currency_symbol': 'USD',
#   'totalAssets': '9022000000.00',
#   'intangibleAssets': '538000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '181000000.00',
#   'totalLiab': '3897000000.00',
#   'totalStockholderEquity': '5125000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '457000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '178000000.00',
#   'otherLiab': '981000000.00',
#   'goodWill': '3112000000.00',
#   'otherAssets': '637000000.00',
#   'cash': '2155000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1118000000.00',
#   'currentDeferredRevenue': '347000000.00',
#   'netDebt': '-357000000.00',
#   'shortTermDebt': None,
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '1798000000.00',
#   'otherStockholderEquity': '5342000000.00',
#   'propertyPlantEquipment': '827000000.00',
#   'totalCurrentAssets': '3812000000.00',
#   'longTermInvestments': '96000000.00',
#   'netTangibleAssets': '1475000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '819000000.00',
#   'longTermDebt': '1798000000.00',
#   'inventory': '657000000.00',
#   'accountsPayable': '314000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-398000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '178000000.00',
#   'treasuryStock': '-1000000.00',
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '637000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '5210000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1798000000.00',
#   'nonCurrentLiabilitiesOther': '981000000.00',
#   'nonCurrentLiabilitiesTotal': '2779000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5343000000.00',
#   'liabilitiesAndStockholdersEquity': '9022000000.00',
#   'cashAndShortTermInvestments': '2155000000.00',
#   'propertyPlantAndEquipmentGross': '827000000.00',
#   'propertyPlantAndEquipmentNet': '827000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '321000000.00'},
#  '2019-01-31': {'date': '2019-01-31',
#   'filing_date': '2019-03-05',
#   'currency_symbol': 'USD',
#   'totalAssets': '8952000000.00',
#   'intangibleAssets': '566000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '169000000.00',
#   'totalLiab': '3916000000.00',
#   'totalStockholderEquity': '5036000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '434000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '90000000.00',
#   'otherLiab': '1023000000.00',
#   'goodWill': '3133000000.00',
#   'otherAssets': '635000000.00',
#   'cash': '2057000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1095000000.00',
#   'currentDeferredRevenue': '346000000.00',
#   'netDebt': '-259000000.00',
#   'shortTermDebt': None,
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '1798000000.00',
#   'otherStockholderEquity': '5324000000.00',
#   'propertyPlantEquipment': '829000000.00',
#   'totalCurrentAssets': '3712000000.00',
#   'longTermInvestments': '77000000.00',
#   'netTangibleAssets': '1337000000.00',
#   'shortTermInvestments': None,
#   'netReceivables': '833000000.00',
#   'longTermDebt': '1798000000.00',
#   'inventory': '653000000.00',
#   'accountsPayable': '315000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-381000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': '90000000.00',
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '635000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '5240000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1798000000.00',
#   'nonCurrentLiabilitiesOther': '1023000000.00',
#   'nonCurrentLiabilitiesTotal': '2821000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5324000000.00',
#   'liabilitiesAndStockholdersEquity': '8952000000.00',
#   'cashAndShortTermInvestments': '2057000000.00',
#   'propertyPlantAndEquipmentGross': '829000000.00',
#   'propertyPlantAndEquipmentNet': '829000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '322000000.00'},
#  '2018-10-31': {'date': '2018-10-31',
#   'filing_date': '2018-12-20',
#   'currency_symbol': 'USD',
#   'totalAssets': '8541000000.00',
#   'intangibleAssets': '491000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '187000000.00',
#   'totalLiab': '3970000000.00',
#   'totalStockholderEquity': '4567000000.00',
#   'deferredLongTermLiab': '0.00',
#   'otherCurrentLiab': '507000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '-336000000.00',
#   'otherLiab': '1000000000.00',
#   'goodWill': '2973000000.00',
#   'otherAssets': '339000000.00',
#   'cash': '2247000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1171000000.00',
#   'currentDeferredRevenue': '324000000.00',
#   'netDebt': '-448000000.00',
#   'shortTermDebt': None,
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '1799000000.00',
#   'otherStockholderEquity': '5308000000.00',
#   'propertyPlantEquipment': '822000000.00',
#   'totalCurrentAssets': '3848000000.00',
#   'longTermInvestments': '68000000.00',
#   'netTangibleAssets': '1103000000.00',
#   'shortTermInvestments': '0.00',
#   'netReceivables': '776000000.00',
#   'longTermDebt': '1799000000.00',
#   'inventory': '638000000.00',
#   'accountsPayable': '340000000.00',
#   'totalPermanentEquity': '4571000000.00',
#   'noncontrollingInterestInConsolidatedEntity': '4000000.00',
#   'temporaryEquityRedeemableNoncontrollingInterests': '0.00',
#   'accumulatedOtherComprehensiveIncome': '-408000000.00',
#   'additionalPaidInCapital': '5308000000.00',
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': '0.00',
#   'retainedEarningsTotalEquity': '-336000000.00',
#   'treasuryStock': '0.00',
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '339000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '4693000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1799000000.00',
#   'nonCurrentLiabilitiesOther': '1000000000.00',
#   'nonCurrentLiabilitiesTotal': '2799000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5308000000.00',
#   'liabilitiesAndStockholdersEquity': '8537000000.00',
#   'cashAndShortTermInvestments': '2247000000.00',
#   'propertyPlantAndEquipmentGross': '822000000.00',
#   'propertyPlantAndEquipmentNet': '822000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '322000000.00'},
#  '2018-07-31': {'date': '2018-07-31',
#   'filing_date': '2018-08-30',
#   'currency_symbol': 'USD',
#   'totalAssets': '8349000000.00',
#   'intangibleAssets': '515000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '180000000.00',
#   'totalLiab': '3781000000.00',
#   'totalStockholderEquity': '4564000000.00',
#   'deferredLongTermLiab': '0.00',
#   'otherCurrentLiab': '413000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '-416000000.00',
#   'otherLiab': '968000000.00',
#   'goodWill': '2933000000.00',
#   'otherAssets': '363000000.00',
#   'cash': '2131000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1014000000.00',
#   'currentDeferredRevenue': '328000000.00',
#   'netDebt': '-332000000.00',
#   'shortTermDebt': '1799000000.00',
#   'shortLongTermDebt': '1799000000.00',
#   'shortLongTermDebtTotal': '1799000000.00',
#   'otherStockholderEquity': '5312000000.00',
#   'propertyPlantEquipment': '801000000.00',
#   'totalCurrentAssets': '3667000000.00',
#   'longTermInvestments': '70000000.00',
#   'netTangibleAssets': '1116000000.00',
#   'shortTermInvestments': '0.00',
#   'netReceivables': '733000000.00',
#   'longTermDebt': '1799000000.00',
#   'inventory': '623000000.00',
#   'accountsPayable': '273000000.00',
#   'totalPermanentEquity': '4568000000.00',
#   'noncontrollingInterestInConsolidatedEntity': '4000000.00',
#   'temporaryEquityRedeemableNoncontrollingInterests': '0.00',
#   'accumulatedOtherComprehensiveIncome': '-335000000.00',
#   'additionalPaidInCapital': '0.00',
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': '0.00',
#   'retainedEarningsTotalEquity': '-416000000.00',
#   'treasuryStock': '0.00',
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '363000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '4682000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1799000000.00',
#   'nonCurrentLiabilitiesOther': '968000000.00',
#   'nonCurrentLiabilitiesTotal': '2767000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5312000000.00',
#   'liabilitiesAndStockholdersEquity': '8345000000.00',
#   'cashAndShortTermInvestments': '2131000000.00',
#   'propertyPlantAndEquipmentGross': '801000000.00',
#   'propertyPlantAndEquipmentNet': '801000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '324000000.00'},
#  '2018-04-30': {'date': '2018-04-30',
#   'filing_date': '2018-05-31',
#   'currency_symbol': 'USD',
#   'totalAssets': '8784000000.00',
#   'intangibleAssets': '314000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '166000000.00',
#   'totalLiab': '4167000000.00',
#   'totalStockholderEquity': '4613000000.00',
#   'deferredLongTermLiab': '0.00',
#   'otherCurrentLiab': '446000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '-412000000.00',
#   'otherLiab': '1002000000.00',
#   'goodWill': '2618000000.00',
#   'otherAssets': '390000000.00',
#   'cash': '3011000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1365000000.00',
#   'currentDeferredRevenue': '333000000.00',
#   'netDebt': '-896000000.00',
#   'shortTermDebt': '315000000.00',
#   'shortLongTermDebt': '2115000000.00',
#   'shortLongTermDebtTotal': '2115000000.00',
#   'otherStockholderEquity': '5332000000.00',
#   'propertyPlantEquipment': '798000000.00',
#   'totalCurrentAssets': '4525000000.00',
#   'longTermInvestments': '139000000.00',
#   'netTangibleAssets': '1681000000.00',
#   'shortTermInvestments': '0.00',
#   'netReceivables': '754000000.00',
#   'longTermDebt': '1800000000.00',
#   'inventory': '594000000.00',
#   'accountsPayable': '271000000.00',
#   'totalPermanentEquity': '4617000000.00',
#   'noncontrollingInterestInConsolidatedEntity': '4000000.00',
#   'temporaryEquityRedeemableNoncontrollingInterests': '0.00',
#   'accumulatedOtherComprehensiveIncome': '-310000000.00',
#   'additionalPaidInCapital': '0.00',
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': '0.00',
#   'retainedEarningsTotalEquity': '-412000000.00',
#   'treasuryStock': '0.00',
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '390000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '4259000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1800000000.00',
#   'nonCurrentLiabilitiesOther': '1002000000.00',
#   'nonCurrentLiabilitiesTotal': '2802000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5332000000.00',
#   'liabilitiesAndStockholdersEquity': '8780000000.00',
#   'cashAndShortTermInvestments': '3011000000.00',
#   'propertyPlantAndEquipmentGross': '798000000.00',
#   'propertyPlantAndEquipmentNet': '798000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '326000000.00'},
#  '2018-01-31': {'date': '2018-01-31',
#   'filing_date': '2018-03-06',
#   'currency_symbol': 'USD',
#   'totalAssets': '8698000000.00',
#   'intangibleAssets': '341000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '151000000.00',
#   'totalLiab': '4172000000.00',
#   'totalStockholderEquity': '4522000000.00',
#   'deferredLongTermLiab': '0.00',
#   'otherCurrentLiab': '403000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '-529000000.00',
#   'otherLiab': '1011000000.00',
#   'goodWill': '2633000000.00',
#   'otherAssets': '3509000000.00',
#   'cash': '2887000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1361000000.00',
#   'currentDeferredRevenue': '321000000.00',
#   'netDebt': '-742000000.00',
#   'shortTermDebt': '345000000.00',
#   'shortLongTermDebt': '2145000000.00',
#   'shortLongTermDebtTotal': '2145000000.00',
#   'otherStockholderEquity': '5317000000.00',
#   'propertyPlantEquipment': '792000000.00',
#   'totalCurrentAssets': '4397000000.00',
#   'longTermInvestments': '140000000.00',
#   'netTangibleAssets': '1548000000.00',
#   'shortTermInvestments': '0.00',
#   'netReceivables': '751000000.00',
#   'longTermDebt': '1800000000.00',
#   'inventory': '608000000.00',
#   'accountsPayable': '292000000.00',
#   'totalPermanentEquity': '4526000000.00',
#   'noncontrollingInterestInConsolidatedEntity': '4000000.00',
#   'temporaryEquityRedeemableNoncontrollingInterests': '0.00',
#   'accumulatedOtherComprehensiveIncome': '-269000000.00',
#   'additionalPaidInCapital': '0.00',
#   'commonStockTotalEquity': '3000000.00',
#   'preferredStockTotalEquity': '0.00',
#   'retainedEarningsTotalEquity': '-529000000.00',
#   'treasuryStock': '-3000000.00',
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '395000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '4301000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': '1800000000.00',
#   'nonCurrentLiabilitiesOther': '1011000000.00',
#   'nonCurrentLiabilitiesTotal': '2811000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': '5320000000.00',
#   'liabilitiesAndStockholdersEquity': '8694000000.00',
#   'cashAndShortTermInvestments': '2887000000.00',
#   'propertyPlantAndEquipmentGross': '792000000.00',
#   'propertyPlantAndEquipmentNet': '792000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '323000000.00'},
#  '2017-10-31': {'date': '2017-10-31',
#   'filing_date': '2017-12-21',
#   'currency_symbol': 'USD',
#   'totalAssets': '8426000000.00',
#   'intangibleAssets': '361000000.00',
#   'earningAssets': None,
#   'otherCurrentAssets': '192000000.00',
#   'totalLiab': '3591000000.00',
#   'totalStockholderEquity': '4831000000.00',
#   'deferredLongTermLiab': '0.00',
#   'otherCurrentLiab': '457000000.00',
#   'commonStock': '3000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '-126000000.00',
#   'otherLiab': '450000000.00',
#   'goodWill': '2607000000.00',
#   'otherAssets': '3500000000.00',
#   'cash': '2678000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1263000000.00',
#   'currentDeferredRevenue': '291000000.00',
#   'netDebt': '-667000000.00',
#   'shortTermDebt': '210000000.00',
#   'shortLongTermDebt': '100000000.00',
#   'shortLongTermDebtTotal': '2011000000.00',
#   'otherStockholderEquity': '5300000000.00',
#   'propertyPlantEquipment': '757000000.00',
#   'totalCurrentAssets': '4169000000.00',
#   'longTermInvestments': '138000000.00',
# ...
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': '402000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': '8425000000.00',
#   'cashAndShortTermInvestments': '996000000.00',
#   'propertyPlantAndEquipmentGross': '1741000000.00',
#   'propertyPlantAndEquipmentNet': '1741000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '466000000.00'},
#  '2000-07-31': {'date': '2000-07-31',
#   'filing_date': '2000-09-01',
#   'currency_symbol': 'USD',
#   'totalAssets': '7827000000.00',
#   'intangibleAssets': None,
#   'earningAssets': None,
#   'otherCurrentAssets': '712000000.00',
#   'totalLiab': '2925000000.00',
#   'totalStockholderEquity': '4902000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '1237000000.00',
#   'commonStock': '5000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '452000000.00',
#   'otherLiab': '415000000.00',
#   'goodWill': None,
#   'otherAssets': '902000000.00',
#   'cash': '703000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '2510000000.00',
#   'currentDeferredRevenue': '361000000.00',
#   'netDebt': '-574000000.00',
#   'shortTermDebt': '129000000.00',
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '129000000.00',
#   'otherStockholderEquity': '6689000000.00',
#   'propertyPlantEquipment': '1581000000.00',
#   'totalCurrentAssets': '5344000000.00',
#   'longTermInvestments': None,
#   'netTangibleAssets': None,
#   'shortTermInvestments': None,
#   'netReceivables': '2167000000.00',
#   'longTermDebt': None,
#   'inventory': '1762000000.00',
#   'accountsPayable': '783000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-2244000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '5000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '902000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '2483000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': '415000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': '7827000000.00',
#   'cashAndShortTermInvestments': '703000000.00',
#   'propertyPlantAndEquipmentGross': '1581000000.00',
#   'propertyPlantAndEquipmentNet': '1581000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '461000000.00'},
#  '2000-04-30': {'date': '2000-04-30',
#   'filing_date': '2000-06-12',
#   'currency_symbol': 'USD',
#   'totalAssets': '7321000000.00',
#   'intangibleAssets': None,
#   'earningAssets': None,
#   'otherCurrentAssets': '568000000.00',
#   'totalLiab': '2679000000.00',
#   'totalStockholderEquity': '4642000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '1250000000.00',
#   'commonStock': '5000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '297000000.00',
#   'otherLiab': '493000000.00',
#   'goodWill': None,
#   'otherAssets': '811000000.00',
#   'cash': '978000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '2186000000.00',
#   'currentDeferredRevenue': '329000000.00',
#   'netDebt': '-880000000.00',
#   'shortTermDebt': '98000000.00',
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '98000000.00',
#   'otherStockholderEquity': '6577000000.00',
#   'propertyPlantEquipment': '1453000000.00',
#   'totalCurrentAssets': '5057000000.00',
#   'longTermInvestments': None,
#   'netTangibleAssets': None,
#   'shortTermInvestments': None,
#   'netReceivables': '1889000000.00',
#   'longTermDebt': None,
#   'inventory': '1622000000.00',
#   'accountsPayable': '509000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-2237000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '5000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '811000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '2264000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': '493000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': '7321000000.00',
#   'cashAndShortTermInvestments': '978000000.00',
#   'propertyPlantAndEquipmentGross': '1453000000.00',
#   'propertyPlantAndEquipmentNet': '1453000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '457000000.00'},
#  '2000-01-31': {'date': '2000-01-31',
#   'filing_date': '2000-03-15',
#   'currency_symbol': 'USD',
#   'totalAssets': '7107000000.00',
#   'intangibleAssets': None,
#   'earningAssets': None,
#   'otherCurrentAssets': '560000000.00',
#   'totalLiab': '2621000000.00',
#   'totalStockholderEquity': '4486000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '1040000000.00',
#   'commonStock': '5000000.00',
#   'capitalStock': None,
#   'retainedEarnings': '131000000.00',
#   'otherLiab': '554000000.00',
#   'goodWill': None,
#   'otherAssets': '717000000.00',
#   'cash': '1368000000.00',
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '2067000000.00',
#   'currentDeferredRevenue': '281000000.00',
#   'netDebt': '-371000000.00',
#   'shortTermDebt': '443000000.00',
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': '997000000.00',
#   'otherStockholderEquity': '6576000000.00',
#   'propertyPlantEquipment': '1408000000.00',
#   'totalCurrentAssets': '4982000000.00',
#   'longTermInvestments': None,
#   'netTangibleAssets': None,
#   'shortTermInvestments': '42000000.00',
#   'netReceivables': '1445000000.00',
#   'longTermDebt': None,
#   'inventory': '1567000000.00',
#   'accountsPayable': '303000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-2226000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '5000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '717000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '2125000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': '554000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': '7107000000.00',
#   'cashAndShortTermInvestments': '1410000000.00',
#   'propertyPlantAndEquipmentGross': '1408000000.00',
#   'propertyPlantAndEquipmentNet': '1408000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '440000000.00'},
#  '1999-10-31': {'date': '1999-10-31',
#   'filing_date': '1999-10-31',
#   'currency_symbol': 'USD',
#   'totalAssets': '5444000000.00',
#   'intangibleAssets': None,
#   'earningAssets': None,
#   'otherCurrentAssets': '404000000.00',
#   'totalLiab': '2062000000.00',
#   'totalStockholderEquity': '3382000000.00',
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': '930000000.00',
#   'commonStock': '4000000.00',
#   'capitalStock': None,
#   'retainedEarnings': None,
#   'otherLiab': None,
#   'goodWill': None,
#   'otherAssets': None,
#   'cash': None,
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': '1681000000.00',
#   'currentDeferredRevenue': '241000000.00',
#   'netDebt': None,
#   'shortTermDebt': None,
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': None,
#   'otherStockholderEquity': '5648000000.00',
#   'propertyPlantEquipment': None,
#   'totalCurrentAssets': '3538000000.00',
#   'longTermInvestments': None,
#   'netTangibleAssets': None,
#   'shortTermInvestments': None,
#   'netReceivables': '1635000000.00',
#   'longTermDebt': None,
#   'inventory': '1499000000.00',
#   'accountsPayable': '510000000.00',
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': '-2270000000.00',
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': '4000000.00',
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': '519000000.00',
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': '1906000000.00',
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': '381000000.00',
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': '5444000000.00',
#   'cashAndShortTermInvestments': None,
#   'propertyPlantAndEquipmentGross': '1387000000.00',
#   'propertyPlantAndEquipmentNet': '1387000000.00',
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '440000000.00'},
#  '1999-07-31': {'date': '1999-07-31',
#   'filing_date': '1999-07-31',
#   'currency_symbol': 'USD',
#   'totalAssets': None,
#   'intangibleAssets': None,
#   'earningAssets': None,
#   'otherCurrentAssets': None,
#   'totalLiab': None,
#   'totalStockholderEquity': None,
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': None,
#   'commonStock': None,
#   'capitalStock': None,
#   'retainedEarnings': None,
#   'otherLiab': None,
#   'goodWill': None,
#   'otherAssets': None,
#   'cash': None,
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': None,
#   'currentDeferredRevenue': None,
#   'netDebt': None,
#   'shortTermDebt': None,
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': None,
#   'otherStockholderEquity': None,
#   'propertyPlantEquipment': None,
#   'totalCurrentAssets': None,
#   'longTermInvestments': None,
#   'netTangibleAssets': None,
#   'shortTermInvestments': None,
#   'netReceivables': None,
#   'longTermDebt': None,
#   'inventory': None,
#   'accountsPayable': None,
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': None,
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': None,
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': None,
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': None,
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': None,
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': None,
#   'cashAndShortTermInvestments': None,
#   'propertyPlantAndEquipmentGross': None,
#   'propertyPlantAndEquipmentNet': None,
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '450000000.00'},
#  '1999-04-30': {'date': '1999-04-30',
#   'filing_date': '1999-04-30',
#   'currency_symbol': 'USD',
#   'totalAssets': None,
#   'intangibleAssets': None,
#   'earningAssets': None,
#   'otherCurrentAssets': None,
#   'totalLiab': None,
#   'totalStockholderEquity': None,
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': None,
#   'commonStock': None,
#   'capitalStock': None,
#   'retainedEarnings': None,
#   'otherLiab': None,
#   'goodWill': None,
#   'otherAssets': None,
#   'cash': None,
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': None,
#   'currentDeferredRevenue': None,
#   'netDebt': None,
#   'shortTermDebt': None,
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': None,
#   'otherStockholderEquity': None,
#   'propertyPlantEquipment': None,
#   'totalCurrentAssets': None,
#   'longTermInvestments': None,
#   'netTangibleAssets': None,
#   'shortTermInvestments': None,
#   'netReceivables': None,
#   'longTermDebt': None,
#   'inventory': None,
#   'accountsPayable': None,
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': None,
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': None,
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': None,
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': None,
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': None,
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': None,
#   'cashAndShortTermInvestments': None,
#   'propertyPlantAndEquipmentGross': None,
#   'propertyPlantAndEquipmentNet': None,
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '461764706.00'},
#  '1999-01-31': {'date': '1999-01-31',
#   'filing_date': '1999-01-31',
#   'currency_symbol': 'USD',
#   'totalAssets': None,
#   'intangibleAssets': None,
#   'earningAssets': None,
#   'otherCurrentAssets': None,
#   'totalLiab': None,
#   'totalStockholderEquity': None,
#   'deferredLongTermLiab': None,
#   'otherCurrentLiab': None,
#   'commonStock': None,
#   'capitalStock': None,
#   'retainedEarnings': None,
#   'otherLiab': None,
#   'goodWill': None,
#   'otherAssets': None,
#   'cash': None,
#   'cashAndEquivalents': None,
#   'totalCurrentLiabilities': None,
#   'currentDeferredRevenue': None,
#   'netDebt': None,
#   'shortTermDebt': None,
#   'shortLongTermDebt': None,
#   'shortLongTermDebtTotal': None,
#   'otherStockholderEquity': None,
#   'propertyPlantEquipment': None,
#   'totalCurrentAssets': None,
#   'longTermInvestments': None,
#   'netTangibleAssets': None,
#   'shortTermInvestments': None,
#   'netReceivables': None,
#   'longTermDebt': None,
#   'inventory': None,
#   'accountsPayable': None,
#   'totalPermanentEquity': None,
#   'noncontrollingInterestInConsolidatedEntity': None,
#   'temporaryEquityRedeemableNoncontrollingInterests': None,
#   'accumulatedOtherComprehensiveIncome': None,
#   'additionalPaidInCapital': None,
#   'commonStockTotalEquity': None,
#   'preferredStockTotalEquity': None,
#   'retainedEarningsTotalEquity': None,
#   'treasuryStock': None,
#   'accumulatedAmortization': None,
#   'nonCurrrentAssetsOther': None,
#   'deferredLongTermAssetCharges': None,
#   'nonCurrentAssetsTotal': None,
#   'capitalLeaseObligations': None,
#   'longTermDebtTotal': None,
#   'nonCurrentLiabilitiesOther': None,
#   'nonCurrentLiabilitiesTotal': None,
#   'negativeGoodwill': None,
#   'warrants': None,
#   'preferredStockRedeemable': None,
#   'capitalSurpluse': None,
#   'liabilitiesAndStockholdersEquity': None,
#   'cashAndShortTermInvestments': None,
#   'propertyPlantAndEquipmentGross': None,
#   'propertyPlantAndEquipmentNet': None,
#   'accumulatedDepreciation': None,
#   'netWorkingCapital': None,
#   'netInvestedCapital': None,
#   'commonStockSharesOutstanding': '462500000.00'}}

# %%
pd.json_normalize(
        js['Financials']["Balance_Sheet"]["quarterly"].values(),   
)
# Out:
#           date filing_date currency_symbol     totalAssets intangibleAssets  \
# 0   2022-07-31  2022-09-01             USD  10484000000.00     849000000.00
# 1   2022-04-30  2022-05-31             USD  10455000000.00     898000000.00
# 2   2022-01-31  2022-03-03             USD  10327000000.00     929000000.00
# 3   2021-10-31  2021-12-17             USD  10705000000.00     981000000.00
# 4   2021-07-31  2021-09-01             USD  10491000000.00    1032000000.00
# ..         ...         ...             ...             ...              ...
# 90  2000-01-31  2000-03-15             USD   7107000000.00             None
# 91  1999-10-31  1999-10-31             USD   5444000000.00             None
# 92  1999-07-31  1999-07-31             USD            None             None
# 93  1999-04-30  1999-04-30             USD            None             None
# 94  1999-01-31  1999-01-31             USD            None             None
#
#    earningAssets otherCurrentAssets      totalLiab totalStockholderEquity  \
# 0           None       258000000.00  5393000000.00          5091000000.00
# 1           None       262000000.00  5333000000.00          5122000000.00
# 2           None       232000000.00  5173000000.00          5154000000.00
# 3           None       222000000.00  5316000000.00          5389000000.00
# 4           None       264000000.00  5545000000.00          4946000000.00
# ..           ...                ...            ...                    ...
# 90          None       560000000.00  2621000000.00          4486000000.00
# 91          None       404000000.00  2062000000.00          3382000000.00
# 92          None               None           None                   None
# 93          None               None           None                   None
# 94          None               None           None                   None
#
#    deferredLongTermLiab  ... preferredStockRedeemable capitalSurpluse  \
# 0                  None  ...                     None   5311000000.00
# 1                  None  ...                     None   5292000000.00
# 2                  None  ...                     None   5290000000.00
# 3                  None  ...                     None   5320000000.00
# 4                  None  ...                     None   5307000000.00
# ..                  ...  ...                      ...             ...
# 90                 None  ...                     None            None
# 91                 None  ...                     None            None
# 92                 None  ...                     None            None
# 93                 None  ...                     None            None
# 94                 None  ...                     None            None
#
#    liabilitiesAndStockholdersEquity cashAndShortTermInvestments  \
# 0                    10484000000.00               1077000000.00
# 1                    10455000000.00               1207000000.00
# 2                    10327000000.00               1158000000.00
# 3                    10705000000.00               1575000000.00
# 4                    10491000000.00               1428000000.00
# ..                              ...                         ...
# 90                    7107000000.00               1410000000.00
# 91                    5444000000.00                        None
# 92                             None                        None
# 93                             None                        None
# 94                             None                        None
#
#    propertyPlantAndEquipmentGross propertyPlantAndEquipmentNet  \
# 0                            None                1054000000.00
# 1                            None                1010000000.00
# 2                            None                 974000000.00
# 3                            None                 945000000.00
# 4                    905000000.00                 905000000.00
# ..                            ...                          ...
# 90                  1408000000.00                1408000000.00
# 91                  1387000000.00                1387000000.00
# 92                           None                         None
# 93                           None                         None
# 94                           None                         None
#
#    accumulatedDepreciation netWorkingCapital netInvestedCapital  \
# 0                     None     1788000000.00      8003000000.00
# 1                     None     1830000000.00      8027000000.00
# 2                     None     1890000000.00      7884000000.00
# 3                     None     2091000000.00      8118000000.00
# 4                     None     1908000000.00      7804000000.00
# ..                     ...               ...                ...
# 90                    None              None               None
# 91                    None              None               None
# 92                    None              None               None
# 93                    None              None               None
# 94                    None              None               None
#
#    commonStockSharesOutstanding
# 0                  299000000.00
# 1                  301000000.00
# 2                  303000000.00
# 3                  305000000.00
# 4                  306000000.00
# ..                          ...
# 90                 440000000.00
# 91                 440000000.00
# 92                 450000000.00
# 93                 461764706.00
# 94                 462500000.00
#
# [95 rows x 64 columns]

# %% [markdown]
# # Get monthly stock data

# %%
import io

# %%
historical = {}

# %%
for sym in tqdm.notebook.tqdm(symbols):
    if sym in historical:
        continue
    
    # Monthly historical price
    df = pd.read_csv(
        io.StringIO(
            requests.get(f"https://eodhistoricaldata.com/api/eod/{sym}?api_token={key}&period=m").text)
    )
    df["symbol"] = sym
    
    historical[sym] = df
# Out:
#   0%|          | 0/503 [00:00<?, ?it/s]

# %%
df_hist = pd.concat(historical.values())

# %%
df_hist.to_csv("./monthly_price.csv", index=False)
